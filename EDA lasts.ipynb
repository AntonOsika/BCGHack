# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/data/GAMMA_hackathon/'
# !ls {path}
df = pd.read_csv(path + 'customer_data.csv')
# Out:
#  customer_data.csv	 'Gammathon attendee Instructions.pdf'
#  example_submission.csv

# %%
df
# Out:
#           customer_id       month  months_since_joined  referred_friends  \
# 0                   2  2016-02-01                   50                 3
# 1                   4  2016-02-01                   50                 1
# 2                   7  2016-02-01                   50                 1
# 3                  14  2016-02-01                   50                 0
# 4                  19  2016-02-01                   50                 2
# ...               ...         ...                  ...               ...
# 11436133      1204352  2019-09-01                    1                 0
# 11436134      1204353  2019-09-01                    1                 0
# 11436135      1204354  2019-09-01                    1                 3
# 11436136      1204355  2019-09-01                    1                 0
# 11436137      1204356  2019-09-01                    1                 1
#
#           transaction_count  transaction_value           clv  \
# ...

# %%
len(df)
# Out:
# 11436138

# %%
df.describe()
# Out:
#         customer_id  months_since_joined  referred_friends  transaction_count  \
# count  1.143614e+07         1.143614e+07      1.143614e+07       1.143614e+07
# mean   6.086582e+05         2.210391e+01      9.669775e-01       2.936650e+01
# std    2.847427e+05         1.978018e+01      9.877185e-01       1.471019e+01
# min    2.000000e+00         1.000000e+00      0.000000e+00       0.000000e+00
# 25%    4.067390e+05         6.000000e+00      0.000000e+00       1.900000e+01
# 50%    6.195790e+05         1.600000e+01      1.000000e+00       2.600000e+01
# 75%    8.241590e+05         3.400000e+01      2.000000e+00       3.600000e+01
# max    1.204356e+06         9.300000e+01      9.000000e+00       1.410000e+02
#
#        transaction_value           clv  total_reward_points  \
# count       1.143614e+07  1.143614e+07         1.143614e+07
# mean        1.504392e+02  3.600556e+03         5.648918e+03
# std         1.645431e+02  5.712062e+03         1.374896e+04
# ...

# %%
df.customer_id.value_counts().hist()
plt.show()

# %%
df.tail?

# %%
lasts = df.sort_values('month').groupby('customer_id').tail(1)
lasts.head()
# Out:
#         customer_id       month  months_since_joined  referred_friends  \
# 136603       484793  2016-02-01                    7                 0
# 136665       484906  2016-02-01                    7                 1
# 136653       484878  2016-02-01                    7                 0
# 136658       484887  2016-02-01                    7                 1
# 136664       484903  2016-02-01                    7                 0
#
#         transaction_count  transaction_value         clv  total_reward_points  \
# 136603               19.0          47.747164  369.225561           266.708234
# 136665               26.0          72.513607  560.742773           565.329134
# 136653               30.0          45.074418  348.557393           491.276793
# 136658               14.0          33.911550  262.235698            96.583180
# 136664               11.0          28.450272  220.004012            77.437503
#
#         earned_reward_points cluster  churned
# ...

# %%
lasts.describe()
# Out:
#         customer_id  months_since_joined  referred_friends  transaction_count  \
# count  8.368330e+05        836833.000000      836833.00000      836833.000000
# mean   7.622006e+05            17.561375           0.82660          26.039277
# std    2.837206e+05            19.751960           0.93275          14.071841
# min    2.000000e+00             1.000000           0.00000           0.000000
# 25%    5.767320e+05             4.000000           0.00000          17.000000
# 50%    7.859400e+05             9.000000           1.00000          23.000000
# 75%    9.951480e+05            25.000000           1.00000          30.000000
# max    1.204356e+06            93.000000           9.00000         141.000000
#
#        transaction_value            clv  total_reward_points  \
# count      836833.000000  836833.000000        836833.000000
# mean          114.136162    2515.032754          4540.395086
# std           152.943692    5291.274312         14894.920802
# ...

# %%
lasts.loc[~lasts.churned].describe()
# Out:
#         customer_id  months_since_joined  referred_friends  transaction_count  \
# count  3.009670e+05        300967.000000     300967.000000      300967.000000
# mean   8.213076e+05            26.877737          0.977416          31.821901
# std    3.277934e+05            24.271115          0.989263          17.287494
# min    2.000000e+00             1.000000          0.000000           0.000000
# 25%    6.050745e+05             7.000000          0.000000          20.000000
# 50%    9.168100e+05            19.000000          1.000000          27.000000
# 75%    1.099624e+06            41.000000          2.000000          39.000000
# max    1.204356e+06            93.000000          8.000000         141.000000
#
#        transaction_value            clv  total_reward_points  \
# count      300967.000000  300967.000000        300967.000000
# mean          186.224074    4890.615275          9490.906752
# std           217.671704    7606.236144         22604.426141
# ...

# %%
lasts.loc[~lasts.churned].clv.hist(bins=40)

# %%
lasts.loc[~lasts.churned].groupby('cluster').clv.describe()
# Out:
#             count         mean          std  min         25%          50%  \
# cluster
# A         58411.0  4191.671337  6883.926199  0.0  352.109948  1110.247115
# B        152708.0  5257.770024  7960.823152  0.0  552.393031  1655.401134
# C         89848.0  4720.979300  7396.155083  0.0  454.362169  1401.972321
#
#                  75%           max
# cluster
# A        4689.717243  53639.194726
# B        6330.778090  62473.600968
# C        5518.716600  64239.297873
